# %%
print("hello world")
# Out:
# hello world

# %%
from pymongo import MongoClient
import os
from dotenv import load_dotenv

load_dotenv()

client = MongoClient(os.getenv("MONGO_URI"))
db = client[os.getenv("MONGO_DB_NAME")]

db.test.insert_one({"msg": "Atlas working 🚀"})

print("✅ Connected to MongoDB Atlas")
# Out:
# ✅ Connected to MongoDB Atlas

# %%
import os
from dotenv import load_dotenv

load_dotenv()

uri = os.getenv("MONGO_URI")
print(repr(uri))  # repr() will reveal hidden characters
# Out:
# 'mongodb+srv://aira_user:RrsHA9wKO6f6VP3p@cluster0.ouwd0bg.mongodb.net/?appName=Cluster0'

# %%
from pymongo import MongoClient
import os
from dotenv import load_dotenv

load_dotenv()

client = MongoClient(os.getenv("MONGO_URI"))
db = client["aira"]

db.test.insert_one({"msg": "Working ✅"})
print("Connected!")
# Out:
# Connected!
